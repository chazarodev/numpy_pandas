# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(2,3))
arr
# Out:
# array([[3, 2, 8],
#        [9, 5, 4]])

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.reshape(6,1)
# Out:
# array([[3],
#        [2],
#        [8],
#        [9],
#        [5],
#        [4]])

# %%
np.reshape(arr, (3, 2))
# Out:
# array([[3, 2],
#        [8, 9],
#        [5, 4]])

# %%
np.reshape(arr,(3,2),'C')
# Out:
# array([[3, 2],
#        [8, 9],
#        [5, 4]])

# %%
np.reshape(arr,(3,2),'F')
# Out:
# array([[3, 5],
#        [9, 8],
#        [2, 4]])

# %%
np.reshape(arr, (3,2),'A')
# Out:
# array([[3, 2],
#        [8, 9],
#        [5, 4]])
